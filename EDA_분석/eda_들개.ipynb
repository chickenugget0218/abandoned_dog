# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

import seaborn as sns
# os에 따른 Font 깨짐 제거를 위해 Font 지정 
import os 
if os.name == 'nt' :  # Windows OS 
    font_family = "Malgun Gothic"
else: # MAC OS 
    font_family = "AppleGothic"
    
# - 값이 깨지는 문제 해결을 위해 파라미터 값 설정 
sns.set(font=font_family, rc ={"axes.unicode_minus" : False})

# %%
df = pd.read_csv('wild_dog.csv', encoding='euc-kr')

# %%
df.head(10)
df.tail(10)
# Out:
#           resc_reprt_no acdnt_cause prcs_result_se_nm  dclr_ymd  dclr_tm  \
# 4199  20215001106S00547        동물포획              안전조치  20211223   214400
# 4200  20215002110S00281        동물포획              안전조치  20211225   164000
# 4201  20215003201S01436        동물포획              안전조치  20211226   144500
# 4202  20215001402S00861        동물포획              안전조치  20211227   100700
# 4203  20215002110S00282        동물포획              안전조치  20211229    83300
# 4204  20215001106S00549        동물포획              안전조치  20211229   162400
# 4205  20215003106S00263        동물포획              안전조치  20211230    91400
# 4206  20215003106S00264        동물포획              안전조치  20211230    94000
# 4207  20215001101S00351        동물포획              안전조치  20211231    91500
# 4208  20215001110S00761        동물포획                기타  20211231   123800
#
#       dclr_yr season_se_nm  qu_se_nm  dclr_mm  dclr_dd  ...  \
# 4199     2021           겨울         4       12       23  ...
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4209 entries, 0 to 4208
# Data columns (total 61 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   resc_reprt_no          4209 non-null   object
#  1   acdnt_cause            4209 non-null   object
#  2   prcs_result_se_nm      4209 non-null   object
#  3   dclr_ymd               4209 non-null   int64
#  4   dclr_tm                4209 non-null   int64
#  5   dclr_yr                4209 non-null   int64
#  6   season_se_nm           4209 non-null   object
#  7   qu_se_nm               4209 non-null   int64
#  8   dclr_mm                4209 non-null   int64
#  9   dclr_dd                4209 non-null   int64
#  10  dclr_hh                4209 non-null   int64
#  11  dclr_mi                4209 non-null   int64
#  12  daywk                  4209 non-null   object
#  13  dsp_ymd                4209 non-null   int64
# ...

# %%
df.count()
# Out:
# resc_reprt_no         4209
# acdnt_cause           4209
# prcs_result_se_nm     4209
# dclr_ymd              4209
# dclr_tm               4209
#                       ...
# time_unit_humidity    4209
# time_unit_msnf          20
# frstt_nm              4209
# ward_nm               4209
# lfdau_nm               185
# Length: 61, dtype: int64

# %%
df['season_se_nm'].value_counts(ascending=False)  #유기동물발생빈도
# Out:
# 여름    1333
# 가을    1254
# 봄      906
# 겨울     716
# Name: season_se_nm, dtype: int64

# %%
season = pd.value_counts(df['season_se_nm'].values, sort=True)
season.plot.bar()
season.plot.bar(grid=True, figsize=(10,8), fontsize=15, color='y')  # figsize, fontsize 조정

plt.title('계절별들개발생빈도')
# x축 라벨 설정
plt.xlabel('계절')
# x축 라벨 설정
plt.ylabel('들개수')
# 막대 그래프(x, y)
#plt.bar(df['시도'], df['시도'].sum)
# 그래프 출력 - show,savefig둘중하나택
#plt.show()
#x축안잘리게
plt.tight_layout()

# 그래프저장
#plt.savefig(f'./bar_plot.jpg', dpi=300)

# %%
df['dclr_yr'].value_counts(ascending=False)  #유기동물발생빈도
# Out:
# 2020    911
# 2021    858
# 2019    748
# 2018    650
# 2017    629
# 2016    413
# Name: dclr_yr, dtype: int64

# %%
season = pd.value_counts(df['dclr_yr'].values, sort=True)
season.plot.bar()
season.plot.bar(grid=True, figsize=(10,8), fontsize=15)  # figsize, fontsize 조정


plt.title('년도별들개발생빈도')
# x축 라벨 설정
plt.xlabel('년도')
# x축 라벨 설정
plt.ylabel('들개수')
plt.show()

# %%
df['acdnt_place_nm'].value_counts(ascending=False)  #유기동물발생빈도
# Out:
# 도로, 철도     1117
# 단독주택        796
# 기타          412
# 도로. 철도      375
# 논밭,축사       238
# 공동주택        225
# 하천,바다       119
# 판매시설        110
# 숙박시설        102
# 도로교통         94
# 도시공원         85
# 논밭.축사        80
# 교육·연구시설      75
# 산            52
# 공장·창고        52
# 하천.바다        35
# 작업·공사장       31
# 운동시설         30
# 논밭ㆍ축사        29
# 업무시설         26
# 종교시설         22
# 하천ㆍ바다        21
# 상가ㆍ시장        14
# 빌라           12
# 노유자시설        10
# 작업ㆍ공사장        9
# 아파트           9
# 학교ㆍ유치원        8
# 빌딩ㆍ사무실        6
# 의료시설          5
# 공원            5
# 운수시설          4
# 지하맨홀          1
# Name: acdnt_place_nm, dtype: int64

# %%
place = pd.value_counts(df['acdnt_place_nm'].values, sort=True)
place.plot.bar()
place.plot.bar(grid=True, figsize=(10,8), fontsize=15)  # figsize, fontsize 조정


plt.title('장소별들개발생빈도')
# x축 라벨 설정
plt.xlabel('장소')
# x축 라벨 설정
plt.ylabel('발생수')
plt.show()

# %%
df['sigungu_nm'].value_counts(ascending=False)  #유기동물발생빈도
# Out:
# 제주시     2697
# 서귀포시    1512
# Name: sigungu_nm, dtype: int64

# %%
df['cty_frmvl_se'].value_counts(ascending=False)  #유기동물발생빈도
# Out:
# 농촌    2250
# 도시    1959
# Name: cty_frmvl_se, dtype: int64

# %%
df['emd_nm'].value_counts(ascending=False)  #유기동물발생빈도
# Out:
# 애월읍     350
# 구좌읍     308
# 조천읍     289
# 한림읍     231
# 성산읍     223
#        ...
# 추자면       4
# 도련이동      4
# 회수동       4
# 회천동       4
# 영남동       3
# Name: emd_nm, Length: 73, dtype: int64

# %%
place = pd.value_counts(df['emd_nm'].values, sort=True)
place.plot.bar()
place.plot.bar(grid=True, figsize=(10,8), fontsize=15)  # figsize, fontsize 조정


plt.title('장소별들개발생빈도')
# x축 라벨 설정
plt.xlabel('장소')
# x축 라벨 설정
plt.ylabel('발생수')
plt.show()
